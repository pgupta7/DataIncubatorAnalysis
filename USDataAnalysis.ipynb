# %%
import pandas as pd
import numpy as np
import glob
import datetime
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('EdStatsData.csv')

# %%
df.describe()
# Out:
#                1970          1971          1972          1973          1974  \
# count  7.228800e+04  3.553700e+04  3.561900e+04  3.554500e+04  3.573000e+04
# mean   1.974772e+09  4.253638e+09  4.592365e+09  5.105006e+09  5.401493e+09
# std    1.211687e+11  1.804814e+11  1.914083e+11  2.059170e+11  2.112150e+11
# min   -1.435564e+00 -1.594625e+00 -3.056522e+00 -4.032582e+00 -4.213563e+00
# 25%    8.900000e-01  8.853210e+00  9.240920e+00  9.595200e+00  9.861595e+00
# 50%    6.317724e+00  6.316240e+01  6.655139e+01  6.969595e+01  7.087760e+01
# 75%    6.251250e+01  5.655200e+04  5.863650e+04  6.202900e+04  6.383675e+04
# max    1.903929e+13  1.986457e+13  2.100916e+13  2.238367e+13  2.282991e+13
#
#                1975          1976          1977          1978          1979  \
# count  8.730600e+04  3.748300e+04  3.757400e+04  3.757600e+04  3.680900e+04
# mean   2.314288e+09  5.731808e+09  6.124437e+09  6.671489e+09  7.436724e+09
# ...

# %%
df11=df.loc[df['Country Name']=='United States']
df12=df11.loc[df11['Indicator Code']=='SL.UEM.TOTL.FE.ZS']
titleS=df12['Indicator Name'].values[0]
# df12.loc[:,'1970':'2005']

# %%
df13=pd.DataFrame(df12.iloc[0].values,df12.iloc[0].index)
df13=df13[4:-1]
df13[0]=pd.to_numeric(df13[0],errors='coerce')
df14=df13.loc[~pd.isna(df13[0])]
df14.count()
# pd.to_numeric(df14.columns,errors='coerce')
# Out:
# 0    26
# dtype: int64

# %%
plt.figure()
a=df14.plot(lw=2,figsize=(20,7),title=titleS,fontsize=14)
plt.xticks(list(range(26)), df14.index, fontsize=12)
plt.ylabel('Unemployment percentage',fontsize=14)
plt.xlabel('year',fontsize=14)
plt.show()

# %%
df11=df.loc[df['Country Name']=='United States']
df12=df11.loc[df11['Indicator Code']=='PRJ.ATT.15UP.4.MF']
titleS=df12['Indicator Name'].values[0]
df13=pd.DataFrame(df12.iloc[0].values,df12.iloc[0].index)
df13=df13[4:-1]
df13[0]=pd.to_numeric(df13[0],errors='coerce')
df14=df13.loc[~pd.isna(df13[0])]
df14.count()
# Out:
# 0    19
# dtype: int64

# %%
plt.figure()
a=df14.plot(lw=2,figsize=(20,7),title=titleS,fontsize=14)
plt.xticks(list(range(19)), df14.index, fontsize=14)
plt.ylabel('Percentage of youths over 15',fontsize=14)
plt.xlabel('year',fontsize=14)
plt.show()

# %%
df11=df.loc[df['Country Name']=='United States']
# df12=df11.loc[df11['Indicator Code']=='SL.UEM.TOTL.FE.ZS']
# titleS=df12['Indicator Name'].values[0]

# %%
strV=df11['Indicator Name'].values
strV
# Out:
# array(['Adjusted net enrolment rate, lower secondary, both sexes (%)',
#        'Adjusted net enrolment rate, lower secondary, female (%)',
#        'Adjusted net enrolment rate, lower secondary, gender parity index (GPI)',
#        ..., 'Youth literacy rate, population 15-24 years, female (%)',
#        'Youth literacy rate, population 15-24 years, gender parity index (GPI)',
#        'Youth literacy rate, population 15-24 years, male (%)'],
#       dtype=object)

# %%
df11.to_csv('demo.csv',sep=',')

# %%
df_1=pd.read_csv('EdStatsFootNote.csv')
df_1=df_1.rename(index=str, columns={"CountryCode": "Country Code", "SeriesCode": "Indicator Code"})
df_1.head()
# Out:
#   Country Code  Indicator Code    Year          DESCRIPTION  Unnamed: 4
# 0          ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1          ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2          ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3          ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4          ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %%
df_2=df.append(df_1)
# Out:
# C:\Users\Prasoon\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
df_2.head
# Out:
# Index(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Country Code', 'Country Name', 'DESCRIPTION',
#        'Indicator Code', 'Indicator Name', 'Unnamed: 4', 'Unnamed: 69',
#        'Year'],
#       dtype='object')

# %%
df11=df_2.loc[df_2['Country Code']=='USA']
df11=df11.loc[df11['Indicator Code']=='SE.TER.GRAD.AG.FE.ZS']
df11=df11.loc[~(df11['Indicator Name'].isnull())]
df12=pd.DataFrame(df11.iloc[0].values,df11.iloc[0].index)
df12=df12[:-8]

# %%
plt.figure()
a=df12.plot(lw=2,figsize=(20,7),title=titleS,fontsize=14)
plt.xticks(list(range(df12.size)), df12.index, fontsize=14)
plt.ylabel('Percentage of youths over 15',fontsize=14)
plt.xlabel('year',fontsize=14)
plt.xticks( rotation='vertical')
plt.show()

# %%
indicatorCode=['SE.TER.GRAD.ED.FE.ZS',
'SE.TER.GRAD.HU.FE.ZS',
'SE.TER.GRAD.SC.FE.ZS',
'SE.TER.GRAD.SS.FE.ZS']
plt.figure(figsize=(20,10))
comb=pd.DataFrame([])
for i in range(len(indicatorCode)):
    df11=df_2.loc[df_2['Country Code']=='USA']
    df11=df11.loc[df11['Indicator Code']==indicatorCode[i]]
    df11=df11.loc[~(df11['Indicator Name'].isnull())]
    df12=pd.DataFrame(df11.iloc[0].values,df11.iloc[0].index)
    descrip=df11['Indicator Name'].values[0]
    df12=df12[:-8]
    df12=df12.rename(index=str, columns={0:descrip})
    comb=pd.concat([comb,df12],axis=1,sort=False)
    ax=plt.plot(df12, label=descrip)
#     plt.legend(df12['Description'].values, )

plt.xticks(list(range(30,46,1)), df12.index[30:46], fontsize=14)
plt.ylabel('Percentage',fontsize=20)
plt.xlabel('year',fontsize=20)
plt.xticks( rotation='vertical')
plt.yticks( fontsize=14)
plt.legend(fontsize=14,loc='best',bbox_to_anchor=(0.5, 0.5, 0.5, 0.75))
plt.show()

# %%
indicatorCode=['SE.TER.GRAD.AG.FE.ZS',
'SE.TER.GRAD.EN.FE.ZS',
'SE.TER.GRAD.HL.FE.ZS',
'SE.TER.GRAD.OT.FE.ZS',
'SE.TER.GRAD.SV.FE.ZS']
plt.figure(figsize=(20,10))
for i in range(len(indicatorCode)):
    df11=df_2.loc[df_2['Country Code']=='USA']
    df11=df11.loc[df11['Indicator Code']==indicatorCode[i]]
    df11=df11.loc[~(df11['Indicator Name'].isnull())]
    df12=pd.DataFrame(df11.iloc[0].values,df11.iloc[0].index)
    descrip=df11['Indicator Name'].values[0]
    df12=df12[:-8]
    df12=df12.rename(index=str, columns={0:descrip})
    comb=pd.concat([comb,df12],axis=1,sort=False)
    ax=plt.plot(df12, label=descrip)
#     plt.legend(df12['Description'].values, )

plt.xticks(list(range(30,46,1)), df12.index[30:46], fontsize=14)
plt.ylabel('Percentage',fontsize=20)
plt.xlabel('year',fontsize=20)
plt.xticks( rotation='vertical')
plt.yticks( fontsize=14)
plt.legend(fontsize=14,loc='best',bbox_to_anchor=(0.5, 0.5, 0.5, 0.75))
plt.show()

# %%
indicatorCode=['UIS.FOSEP.56.F600.F',
'UIS.FOSEP.56.F140.F',
'UIS.FOSEP.56.F500.F',
'UIS.FOSEP.56.F700.F',
'UIS.FOSEP.56.F200.F',
'UIS.FOSEP.56.FUK.F',
'UIS.FOSEP.56.F400.F',
'UIS.FOSEP.56.F800.F',
'UIS.FOSEP.56.F300.F',

]
comb=pd.DataFrame([])
plt.figure(figsize=(20,10))
for i in range(len(indicatorCode)):
    df11=df_2.loc[df_2['Country Code']=='USA']
    df11=df11.loc[df11['Indicator Code']==indicatorCode[i]]
    df11=df11.loc[~(df11['Indicator Name'].isnull())]
    df12=pd.DataFrame(df11.iloc[0].values,df11.iloc[0].index)
    descrip=df11['Indicator Name'].values[0]
    df12=df12[:-8]
    df12=df12.rename(index=str, columns={0:descrip})
    comb=pd.concat([comb,df12],axis=1,sort=False)
    ax=plt.plot(df12, label=descrip)
#     plt.legend(df12['Description'].values, )

plt.xticks(list(range(40,46,1)), df12.index[40:46], fontsize=14)
plt.ylabel('Percentage',fontsize=20)
plt.xlabel('year',fontsize=20)
plt.xticks( rotation='vertical')
plt.yticks( fontsize=14)
plt.legend(fontsize=14,loc='best',bbox_to_anchor=(0.5, 0.5, 0.5, 0.9))
plt.show()

# %%
indicatorCode=[
'UIS.FOSEP.56.F300.F',
'UIS.FOSEP.56.F700.F',
'UIS.FOSEP.56.F400.F',
]
colors=['C2','C3','C4']
comb=pd.DataFrame([])
plt.figure(figsize=(20,5))
for i in range(len(indicatorCode)):
    df11=df_2.loc[df_2['Country Code']=='USA']
    df11=df11.loc[df11['Indicator Code']==indicatorCode[i]]
    df11=df11.loc[~(df11['Indicator Name'].isnull())]
    df12=pd.DataFrame(df11.iloc[0].values,df11.iloc[0].index)
    descrip=df11['Indicator Name'].values[0]
    df12=df12[:-8]
    df12=df12.rename(index=str, columns={0:descrip})
    comb=pd.concat([comb,df12],axis=1,sort=False)
    ax=plt.plot(df12, label=descrip,lw=2,color=colors[i])
    
indicatorCode=[
'SE.TER.GRAD.SS.FE.ZS',
'SE.TER.GRAD.HL.FE.ZS',
'SE.TER.GRAD.SC.FE.ZS',
]
for i in range(len(indicatorCode)):
    df11=df_2.loc[df_2['Country Code']=='USA']
    df11=df11.loc[df11['Indicator Code']==indicatorCode[i]]
    df11=df11.loc[~(df11['Indicator Name'].isnull())]
    df12=pd.DataFrame(df11.iloc[0].values,df11.iloc[0].index)
    descrip=df11['Indicator Name'].values[0]
    df12=df12[:-8]
    df12=df12.rename(index=str, columns={0:descrip})
    comb=pd.concat([comb,df12],axis=1,sort=False)
    ax=plt.plot(df12, label=descrip,color=colors[i],lw=6)

plt.xticks(list(range(30,46,1)), df12.index[30:46], fontsize=14)
plt.ylabel('Percentage',fontsize=20)
plt.xlabel('year',fontsize=20)
plt.xticks( rotation='vertical')
plt.yticks( fontsize=14)
plt.legend(fontsize=14,loc='best',bbox_to_anchor=(0.5, 0.5, 0.5, 1.1))
plt.show()
